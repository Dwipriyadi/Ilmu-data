# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/kokocamp/vlog101/master/vlog101.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    CustomerID     Sex  Usia  Gaji (juta)  Skor Belanja (1-100)
# 0           1    Pria    19           15                    39
# 1           2    Pria    21           15                    81
# 2           3  Wanita    20           16                     6
# 3           4  Wanita    23           16                    77
# 4           5  Wanita    31           17                    40

# %%
data.describe()
# Out:
#        CustomerID        Usia  Gaji (juta)  Skor Belanja (1-100)
# count  200.000000  200.000000   200.000000            200.000000
# mean   100.500000   38.850000    60.560000             50.200000
# std     57.879185   13.969007    26.264721             25.823522
# min      1.000000   18.000000    15.000000              1.000000
# 25%     50.750000   28.750000    41.500000             34.750000
# 50%    100.500000   36.000000    61.500000             50.000000
# 75%    150.250000   49.000000    78.000000             73.000000
# max    200.000000   70.000000   137.000000             99.000000

# %%
sns.countplot(x='Sex',data=vlog101)
plt.title('Distribusi Sex')
# Out:
# Text(0.5, 1.0, 'Distribusi Sex')

# %%
vlog101.hist('Usia',bins=35)
plt.title('Distribusi usia')
plt.xlabel('Usia')
# Out:
# Text(0.5, 0, 'Usia')

# %%
vlog101.hist('Gaji (juta)')
plt.title('Distribusi Gaji')
plt.xlabel('Juta')
# Out:
# Text(0.5, 0, 'Juta')

# %%
plt.hist('Gaji (juta)', data=vlog101[vlog101['Sex']=='Pria'],alpha=0.5,label='Pria')
plt.hist('Gaji (juta)', data=vlog101[vlog101['Sex']=='Wanita'],alpha=0.5,label='Wanita')
plt.xlabel('Gaji (juta)')
plt.legend()

# %%
Pria = vlog101[vlog101['Sex']=='Pria']
Wanita = vlog101[vlog101['Sex']=='Wanita']

print(Pria['Skor Belanja (1-100)'].mean())
print(Wanita['Skor Belanja (1-100)'].mean())
# Out:
# 48.51136363636363
# 51.526785714285715

# %%
sns.scatterplot('Usia','Gaji (juta)', hue='Sex',data=vlog101)
plt.title('Usia dan Gaji berdasarkan Sex')
# Out:
# Text(0.5, 1.0, 'Usia dan Gaji berdasarkan Sex')

# %%
sns.heatmap(vlog101.corr(),annot=True)

# %%
sns.scatterplot('Usia','Skor Belanja (1-100)', hue='Sex',data=vlog101)
plt.title('Usia dan Skor belanja berdasarkan Sex')
# Out:
# Text(0.5, 1.0, 'Usia dan Skor belanja berdasarkan Sex')

# %%
sns.heatmap(Wanita.corr(),annot=True)
plt.title('korelasi hetmap khusus wanita')
# Out:
# Text(0.5, 1, 'korelasi hetmap khusus wanita')

# %%
sns.heatmap(Pria.corr(),annot=True)
plt.title('korelasi hetmap khusus pria')
# Out:
# Text(0.5, 1, 'korelasi hetmap khusus pria')

# %%
sns.lmplot('Usia','Skor Belanja (1-100)',data=Wanita)
plt.title('Usia dan Skor blanja Wanita')
# Out:
# Text(0.5, 1, 'Usia dan Skor blanja Wanita')

# %%
sns.scatterplot('Gaji (juta)','Skor Belanja (1-100)', hue='Sex',data=vlog101)
plt.title('gaji dan Skor belanja berdasarkan Sex')
# Out:
# Text(0.5, 1.0, 'gaji dan Skor belanja berdasarkan Sex')
